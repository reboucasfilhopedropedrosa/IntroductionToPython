# %% [markdown]
# ![download.png](data:image/png;base64,...)
# # **Pandas** - Biblioteca Python para manipulação de Dados

# %% [markdown]
# ### Quando o assunto é Python, o que não deve se pensar e o que deve se pensar sobre Pandas 🐼

# %% [markdown]
# - Pandas, no universo da programação com Python se parece BEM MENOS com isso:
#
# ![pc-pandas.gif](data:image/gif;base64,...)

# %% [markdown]
# - E BEM MAIS com isso:
#
# ![pandaspython.gif](data:image/gif;base64,...)

# %% [markdown]
# - Mas no fim poderá estar assim: programando
#  com manchas escuras (olheiras) ao redor dos olhos como este panda
#
# ![pandas.gif](data:image/gif;base64,...)

# %% [markdown]
# ### O mundo dos dados e a tarefa de manipulá-los 📊

# %% [markdown]
# Uma tarefa de **grande utilidade prática** na computação é a manipulação de dados. Manipular, preparar, limpar, extrair informações e tirar conclusões de conjuntos de dados é algo extremamente necessário e importante para muitas tarefas. No nosso caso, temos por objetivo apriori o estudo de Machine Learning (ML), usaremos os dados que manipulamos para "ensinar" (o termo mais apropriado é treinar) algoritmos de ML para realizarem atividades diversas no Reconhecimento de Padrões, como Classificação ou Regressão.

# %% [markdown]
# > Para manipular dados com Python utilizaremos a biblioteca **Pandas**

# %% [markdown]
# > **Dados** no caso são porções de informações que permitem chegar ao conhecimento de algo.

# %% [markdown]
# Utilizaremos Conjuntos de dados (usaremos muito a palavra inglesa *Dataset*) no formato de tabela, como um arquivo Excel, porém os dados e a análise e manipulação dos mesmos podem se dar por diversos meios, como bancos de dados também.

# %% [markdown]
# ### Comma-Separated Values (CSVs)

# %% [markdown]
# > Arquivo de texto com valores separados por vírgulas, podendo ser exibido e manipulado como uma tabela
#
# > Utilizaremos Datasets (Conjuntos de dados) formatados nessa extensão de arquivo, o ".csv"

# %% [markdown]
# ### Voltando ao Pandas

# %% [markdown]
# Embora a biblioteca seja muito completa para a manipulação de dados, iremos focar apenas em alguns métodos/funções mais importantes da biblioteca para as atividades que serão realizadas nesse trainee.

# %% [markdown]
# #### Material de consulta

# %% [markdown]
# 1. [Pandas Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf) - PDF com resumo dos principais métodos/funções da biblioteca afim de consulta rápida.
#
# 2. [Pandas Documentation](https://pandas.pydata.org/docs/user_guide/index.html#user-guide) - Site oficial do Pandas com o guia mais completo para utilizar CADA UMA das funções oferecidas pelo Pandas
#
# 3. [Artigo do Medium de introdução ao Pandas](https://medium.com/data-hackers/uma-introdu%C3%A7%C3%A3o-simples-ao-pandas-1e15eea37fa1) - Artigo de fácil leitura e excelente didática para uma introdução ao Pandas
#
# 4. [W3 Schools Pandas Tutorial](https://www.w3schools.com/python/pandas/default.asp) - Outro site muito bom para aprender
#
# 5. [Towards DataScience](https://towardsdatascience.com/) - Sessão do Medium inteiramente dedicada a Ciência de dados
#
# 6. [Papai Google](https://www.google.com.br/?hl=pt-BR)

# %% [markdown]
# #### Instalação e importação

# %% [markdown]
# No Google Colab não é necessário a instalação manual do Pandas pois já vem previamente configurado.
#
# No VS Code, no entanto, é necessário que seja executado um *pip install pandas* **DENTRO DA VENV**.

# %%
# Sempre que importar é aconselhavel seguir a convençao adotada pelos programadores python
# em que apelidaremos o pandas como 'pd' no momento da sua importaçao

import pandas as pd
import numpy as np # numpy quase sempre vai ser utilizado junto com o Pandas

# a partir desta importaçao, ao referenciar a biblioteca nao utilizaremos mais
# a palavra "pandas" mas "pd", como foi referenciado

# %% [markdown]
# ### Com o Pandas instalado e importado podemos iniciar a falar das funções desta biblioteca

# %% [markdown]
# > Pandas tem dois tipos principais de estruturas para organização dos dados: Series (1-Dimensão) e Dataframe (2-Dimensões).

# %% [markdown]
# #### Series

# %%
# Pandas Series

labels = ['linha 1', 'linha 2', 'linha 3']  # lista strings
my_list = [10, 20, 30] # lista numérica
array = np.array([1.1, 1.2, 1.3])  # numpy array
dic = {'x' : 10, 'y' : 20, 'z' : 30}  # dicionário
t = (2, 4, 5, 7) # tupla

serie_1 = pd.Series(array)
serie_1
# Out:
# 0    1.1
# 1    1.2
# 2    1.3
# dtype: float64

# %% [markdown]
# Atente acima ao tipo dos dados da Serie

# %%
# Acessar os valores de uma serie

serie_1[2] # indice numerico
# serie_1['x'] # indice string
# Out:
# 1.3

# %%
# setar index de uma serie utilizando os argumentos da funçao

serie_2 = pd.Series(data=labels, index=my_list)
serie_2
# Out:
# 10    linha 1
# 20    linha 2
# 30    linha 3
# dtype: object

# %% [markdown]
# #### Dataframe

# %%
from numpy.random import rand

matriz = np.random.rand(5, 4)  # gerando uma matriz (array 2-D) com números aleatórios
print(matriz)
# Out:
# [[0.19951538 0.37225039 0.60911483 0.46523862]
#  [0.37855788 0.80263116 0.11079544 0.32329089]
#  [0.26001557 0.13816849 0.60730477 0.0981184 ]
#  [0.61777578 0.59460575 0.57804426 0.7143414 ]
#  [0.30417738 0.80242982 0.31521669 0.52135893]]

# %%
# Dataframe
col = ["col 1", "col 2", "col 3", "col 4"]
dfnum = pd.DataFrame(data=matriz, columns=col)
dfnum
# Out:
#       col 1     col 2     col 3     col 4
# 0  0.199515  0.372250  0.609115  0.465239
# 1  0.378558  0.802631  0.110795  0.323291
# 2  0.260016  0.138168  0.607305  0.098118
# 3  0.617776  0.594606  0.578044  0.714341
# 4  0.304177  0.802430  0.315217  0.521359

# %%
# Dataframe a partir de um dicionario

dicionario = {'nome' : ['maria', 'ana','joao'],
              'idade': [10, 12, 14],
              'altura' : [1.75, 1.67, 1.45]}

dfpessoa = pd.DataFrame(dicionario)

dfpessoa
# Out:
#     nome  idade  altura
# 0  maria     10    1.75
# 1    ana     12    1.67
# 2   joao     14    1.45

# %% [markdown]
# ##### **Selecionar linhas e colunas**

# %%
# Selecionar colunas de um DataFrame

dfpessoa['idade'] # ao selecionar uma coluna, o resultado é uma Serie
idades = dfpessoa['idade']
type(idades)
# Out:
# pandas.core.series.Series

# %%
# Selecionar linhas e colunas pelos labels

display(dfnum.loc[:,'col 2':'col 3'])
display(dfnum.loc[1:2,'col 1'])
# Out:
#       col 2     col 3
# 0  0.372250  0.609115
# 1  0.802631  0.110795
# 2  0.138168  0.607305
# 3  0.594606  0.578044
# 4  0.802430  0.315217
# 1    0.378558
# 2    0.260016
# Name: col 1, dtype: float64

# %%
# selecionar linhas pelo indice numerico

display(dfnum.iloc[:,1])
display(dfnum.iloc[0:1,1:2])
# Out:
# 0    0.853723
# 1    0.508435
# 2    0.902328
# 3    0.585859
# 4    0.599790
# Name: col 2, dtype: float64
#       col 2
# 0  0.853723

# %%
# seleçao condicional
# operadores relacionais > < >= <= == != (True ou False)

display(dfnum[dfnum['col 1'] < 0.40])
display(dfnum)
# Out:
#       col 1     col 2     col 3     col 4
# 0  0.199515  0.372250  0.609115  0.465239
# 1  0.378558  0.802631  0.110795  0.323291
# 2  0.260016  0.138168  0.607305  0.098118
# 4  0.304177  0.802430  0.315217  0.521359
#       col 1     col 2     col 3     col 4
# 0  0.199515  0.372250  0.609115  0.465239
# 1  0.378558  0.802631  0.110795  0.323291
# 2  0.260016  0.138168  0.607305  0.098118
# 3  0.617776  0.594606  0.578044  0.714341
# 4  0.304177  0.802430  0.315217  0.521359

# %% [markdown]
# ##### **Adicionar e remover colunas**

# %%
# adicionar novas colunas
dfpessoa['nova_col'] = [20,30,70]
dfpessoa
# Out:
#     nome  idade  altura  nova_col
# 0  maria     10    1.75        20
# 1    ana     12    1.67        30
# 2   joao     14    1.45        70

# %%
# remover colunas
dfpessoa.drop('nova_col', axis=1, inplace=True) # axis=1 para colunas e axis=0 para linhas
dfpessoa
# Out:
#     nome  idade  altura
# 0  maria     10    1.75
# 1    ana     12    1.67
# 2   joao     14    1.45

# %% [markdown]
# ##### **Valores faltantes**

# %% [markdown]
# Pode acontecer de um dataset ter em suas linhas e colunas valores faltantes, células da tabela em que não há valor algum. Geralmente esses dados (a ausência deles, no caso) **não são importantes** para análises de dados e para treinamento de algoritmos, precisando portanto serem tratados.
#
# > Os valores faltantes em um .csv comumente vão assumir o tipo **'np.nan'**, um nan (not a number) é uma constante que representará um valor que não temos ou que não foi definido. (outras representações são NaN ou NAN)

# %%
# criaremos um novo dataframe para incluirmos nele NaNs

dicio = {'A' : [11, 52, 33, np.nan], 'B' : [15, 40, np.nan, np.nan], 'C' : [10, 12, 43, 77]}

df_nan = pd.DataFrame(data = dicio)
df_nan
# Out:
#       A     B   C
# 0  11.0  15.0  10
# 1  52.0  40.0  12
# 2  33.0   NaN  43
# 3   NaN   NaN  77

# %%
# o método info nos dá informações sobre nosso dataframe
df_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      float64
#  1   B       2 non-null      float64
#  2   C       4 non-null      int64
# dtypes: float64(2), int64(1)
# memory usage: 224.0 bytes

# %%
df_nan.isnull() #identificar os registros faltantes
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False
# 3   True   True  False

# %%
# um artificio muito utilizado para contar o numero de NaNs no dataframe
df_nan.isnull().sum()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %% [markdown]
# > Uma maneira de tratar os valores faltantes é remover as linhas que contém por ao menos um:

# %%
df_nan.dropna() # remover as linhas que contém ao menos um registro faltante
# Out:
#       A     B   C
# 0  11.0  15.0  10
# 1  52.0  40.0  12

# %% [markdown]
# Só que, dependendo do dataset, poderá não dispor de muitas linhas e dados são muito valiosos! quanto mais tiver, melhor poderá ser a análise, tomada de decisão e o treinamento dos algoritmos.

# %%
df_nan.fillna(value=0) # substituir por algum valor padrão em todo dataframe
# Out:
#       A     B   C
# 0  11.0  15.0  10
# 1  52.0  40.0  12
# 2  33.0   0.0  43
# 3   0.0   0.0  77

# %%
df_nan.fillna(value={'A': 1, 'B': np.mean(df_nan['B'])}, inplace = True) # substituir em colunas indicadas
df_nan
# Out:
#       A     B   C
# 0  11.0  15.0  10
# 1  52.0  40.0  12
# 2  33.0  27.5  43
# 3   1.0  27.5  77

# %% [markdown]
# ##### **Juntar dataframes**

# %%
# concatenando dataframes

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                     index=['a', 'b', 'c', 'd'])
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                     index=['e', 'f', 'g', 'h'])
display(df1)
display(df2)
# Out:
#     A   B   C   D
# a  A0  B0  C0  D0
# b  A1  B1  C1  D1
# c  A2  B2  C2  D2
# d  A3  B3  C3  D3
#     A   B   C   D
# e  A4  B4  C4  D4
# f  A5  B5  C5  D5
# g  A6  B6  C6  D6
# h  A7  B7  C7  D7

# %%
df3 = pd.concat([df1, df2])
display(df3)
# Out:
#     A   B   C   D
# a  A0  B0  C0  D0
# b  A1  B1  C1  D1
# c  A2  B2  C2  D2
# d  A3  B3  C3  D3
# e  A4  B4  C4  D4
# f  A5  B5  C5  D5
# g  A6  B6  C6  D6
# h  A7  B7  C7  D7

# %% [markdown]
# **Método Join**

# %%
df4 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                  )
df5 = pd.DataFrame({'E': ['A4', 'A5', 'A6', 'A7'],
                    'F': ['B4', 'B5', 'B6', 'B7'],
                    'G': ['C4', 'C5', 'C6', 'C7'],
                    'H': ['D4', 'D5', 'D6', 'D7']},
                  )

df6 = df4.join(df5)
display(df6)
# Out:
#     A   B   C   D   E   F   G   H
# 0  A0  B0  C0  D0  A4  B4  C4  D4
# 1  A1  B1  C1  D1  A5  B5  C5  D5
# 2  A2  B2  C2  D2  A6  B6  C6  D6
# 3  A3  B3  C3  D3  A7  B7  C7  D7

# %% [markdown]
# ##### **Métodos MUITO úteis**

# %%
df = pd.DataFrame({'col1' : [1, 2, 3, 4, 4, 1],
                   'col2' : [444, 555, 666, 444, 777, 555],
                   'col3' : ['abc', 'def', 'ghi', 'xyz', 'tuv', 'abc']})
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz
# 4     4   777  tuv
# 5     1   555  abc

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.head(3) #exibe as primeiras 5 (default) linhas do dataframe e nome das colunas
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi

# %%
df.tail(3)
# Out:
#    col1  col2 col3
# 3     4   444  xyz
# 4     4   777  tuv
# 5     1   555  abc

# %%
# descrição estatistica do dataframe

df.describe()
# Out:
#            col1        col2
# count  6.000000    6.000000
# mean   2.500000  573.500000
# std    1.378405  129.764017
# min    1.000000  444.000000
# 25%    1.250000  471.750000
# 50%    2.500000  555.000000
# 75%    3.750000  638.250000
# max    4.000000  777.000000

# %%
# Valores únicos de uma coluna

df['col2'].unique()
# Out:
# array([444, 555, 666, 777])

# %%
for col in df.columns:
  print(f'unicos da coluna {col}: {df[col].unique()}')
# Out:
# unicos da coluna col1: [1 2 3 4]
# unicos da coluna col2: [444 555 666 777]
# unicos da coluna col3: ['abc' 'def' 'ghi' 'xyz' 'tuv']

# %%
# Contagem de valores absolutos

df['col2'].value_counts()
# Out:
# 444    2
# 555    2
# 666    1
# 777    1
# Name: col2, dtype: int64

# %%
for col in df.columns:
  print(f'minimo e maximo da coluna {col}: min-{df[col].min()}, max-{df[col].max()}')
# Out:
# minimo e maximo da coluna col1: min-1, max-4
# minimo e maximo da coluna col2: min-444, max-777
# minimo e maximo da coluna col3: min-abc, max-xyz

# %% [markdown]
# #### **Leitura de arquivos e preparação do dataset**

# %% [markdown]
# Utilizaremos para estudar Análise de dados o famoso **dataset Titanic**, por ser um dataset introdutório e por apresentar a necessidade de tratamento dos dados.

# %% [markdown]
# [Titanic dataset page](https://www.kaggle.com/competitions/titanic/data?select=train.csv)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6c408048-0c44-4116-8b6e-f061bf09cfb7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c408048-0c44-4116-8b6e-f061bf09cfb7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# carregando um dataset

df_titanic = pd.read_csv("train.csv") # metodo pandas para leitura de arquivos .csv
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic.shape
# Out:
# (891, 12)
